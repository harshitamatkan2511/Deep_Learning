# %%
#importing packages
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Input

# %%
#Reading dataset
body_fat=pd.read_csv("bodyfat (1).csv")

# %%
body_fat
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     59.0  37.3   21.9    32.0     27.4   17.1
# ...

# %%
#separating into dependent and independent
x=body_fat.drop("BodyFat",axis=1)
y=body_fat["BodyFat"]

# %%
#splitting into train and test
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,train_size=0.8,random_state=0)

# %%
x.shape
# Out:
# (252, 14)

# %%
y.shape
# Out:
# (252,)

# %%
#creating the model with the hidden layers
model = Sequential([
    Input(shape=(14,),name='il',),
    Dense(128,activation='relu',name='d1'),
    Dense(64,activation='relu',name='d2'),
    Dense(32,activation='relu',name='d3'),
    Dense(1,activation='linear',name='ol')])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  d1 (Dense)                  (None, 128)               1920
#
#  d2 (Dense)                  (None, 64)                8256
#
#  d3 (Dense)                  (None, 32)                2080
#
#  ol (Dense)                  (None, 1)                 33
#
# ...
# Total params: 12,289
# Trainable params: 12,289
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = 'mean_squared_error', optimizer = Adam(learning_rate=0.1), metrics=['RootMeanSquaredError'])

# %%
epochs=100

# %%
#fitting to the model
model.fit(x_train,y_train,epochs=epochs)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 1s 4ms/step - loss: 2020968.0000 - root_mean_squared_error: 1421.6075
# Epoch 2/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1009.7859 - root_mean_squared_error: 31.7771
# Epoch 3/100
# 7/7 [==============================] - 0s 4ms/step - loss: 433.4892 - root_mean_squared_error: 20.8204
# Epoch 4/100
# 7/7 [==============================] - 0s 4ms/step - loss: 349.8218 - root_mean_squared_error: 18.7035
# Epoch 5/100
# 7/7 [==============================] - 0s 5ms/step - loss: 246.7776 - root_mean_squared_error: 15.7092
# Epoch 6/100
# 7/7 [==============================] - 0s 3ms/step - loss: 100.8968 - root_mean_squared_error: 10.0447
# Epoch 7/100
# 7/7 [==============================] - 0s 3ms/step - loss: 83.8514 - root_mean_squared_error: 9.1570
# Epoch 8/100
# 7/7 [==============================] - 0s 3ms/step - loss: 75.6521 - root_mean_squared_error: 8.6978
# Epoch 9/100
# ...

# %%
#evaluating the model
loss, accuracy = model.evaluate(x_test, y_test)
# Out:
# 2/2 [==============================] - 0s 11ms/step - loss: 75.7187 - root_mean_squared_error: 8.7017

# %%
print("Test Loss:", loss)
print("Test Rmse:", accuracy)
# Out:
# Test Loss: 75.71874237060547
# Test Rmse: 8.701651573181152
